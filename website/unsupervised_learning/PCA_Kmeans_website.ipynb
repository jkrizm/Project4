# %%
# Import the required libraries and dependencies
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Step 1:  Read in the dataset about the current songs' decades of the playlists.

# %%
# Read the CSV file into a Pandas DataFrame
# Set the index using the Ticker column
songs_df = pd.read_csv(
    Path("final.csv"),                
    # index_col="decade"
)

# Review the DataFrame
songs_df.head()
# Out:
#                        id                 song_name           artist  \
# 0  1H5IfYyIIAlgDX8zguUzns          Suspicious Minds    Elvis Presley
# 1  2xar08Fq5xra2KKZs5Bw9j          I've Got a Woman      Ray Charles
# 2  64VP3skE86iTvdOlbzuIcO       Great Balls Of Fire  Jerry Lee Lewis
# 3  6C7aTTCUWRK7dD379yUT3W       Roll Over Beethoven      Chuck Berry
# 4  3YdKJzcoMZMacISlpY4QoP  I Only Have Eyes for You    The Flamingos
#
#                                              pic_url  \
# 0  https://i.scdn.co/image/ab67616d0000b273fdc0aa...
# 1  https://i.scdn.co/image/ab67616d0000b273f0e951...
# 2  https://i.scdn.co/image/ab67616d0000b27395788c...
# 3  https://i.scdn.co/image/ab67616d0000b273a496dc...
# 4  https://i.scdn.co/image/ab67616d0000b2731ba2d2...
#
#                                          preview_url  release_year  decade  \
# 0  https://p.scdn.co/mp3-preview/e7072dbcb87f4c8c...          1969    1960
# 1  https://p.scdn.co/mp3-preview/425d081433204c6d...          1957    1950
# 2                                                NaN          1961    1960
# 3                                                NaN          1959    1950
# 4  https://p.scdn.co/mp3-preview/8b14a85d40cb0931...          1959    1950
#
#    danceability  energy  key  ...  instrumentalness  liveness  valence  \
# 0         0.487   0.382    7  ...          0.000005     0.411    0.714
# 1         0.556   0.610    9  ...          0.000002     0.258    0.665
# 2         0.533   0.729    7  ...          0.000000     0.159    0.884
# 3         0.715   0.797    3  ...          0.000000     0.209    0.841
# 4         0.552   0.313    5  ...          0.001700     0.120    0.303
#
#      tempo            type                                   uri  \
# 0  116.557  audio_features  spotify:track:1H5IfYyIIAlgDX8zguUzns
# 1  199.373  audio_features  spotify:track:2xar08Fq5xra2KKZs5Bw9j
# 2   78.670  audio_features  spotify:track:64VP3skE86iTvdOlbzuIcO
# 3   92.739  audio_features  spotify:track:6C7aTTCUWRK7dD379yUT3W
# 4   88.554  audio_features  spotify:track:3YdKJzcoMZMacISlpY4QoP
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/1H5IfYyIIAlg...
# 1  https://api.spotify.com/v1/tracks/2xar08Fq5xra...
# 2  https://api.spotify.com/v1/tracks/64VP3skE86iT...
# 3  https://api.spotify.com/v1/tracks/6C7aTTCUWRK7...
# 4  https://api.spotify.com/v1/tracks/3YdKJzcoMZMa...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/1H5I...      261280
# 1  https://api.spotify.com/v1/audio-analysis/2xar...      171467
# 2  https://api.spotify.com/v1/audio-analysis/64VP...      111536
# 3  https://api.spotify.com/v1/audio-analysis/6C7a...      144600
# 4  https://api.spotify.com/v1/audio-analysis/3YdK...      202773
#
#   time_signature
# 0              4
# 1              4
# 2              4
# 3              4
# 4              3
#
# [5 rows x 24 columns]

# %%
songs_df.shape
# Out:
# (1911, 24)

# %%
songs_df.drop(songs_df[(songs_df['release_year'] <1950)].index, inplace=True)
songs_df = songs_df.drop(columns=['id', 'pic_url', 'preview_url', 'release_year', 'type', 'uri', 'track_href', 'analysis_url', 'instrumentalness', 'time_signature', 'mode'])
songs_df = songs_df.dropna()
songs_df.reset_index(drop=True, inplace=True)
songs_df.shape
# Out:
# (1810, 13)

# %%
songs_df.head(65)
# Out:
#                                          song_name           artist  decade  \
# 0                                 Suspicious Minds    Elvis Presley    1960
# 1                                 I've Got a Woman      Ray Charles    1950
# 2                              Great Balls Of Fire  Jerry Lee Lewis    1960
# 3                              Roll Over Beethoven      Chuck Berry    1950
# 4                         I Only Have Eyes for You    The Flamingos    1950
# ..                                             ...              ...     ...
# 60                  (You're The) Devil In Disguise    Elvis Presley    1960
# 61           I Don't Want To Set The World On Fire    The Ink Spots    1990
# 62                            A Teenager's Romance     Ricky Nelson    2000
# 63                      There's a Moon Out Tonight       The Capris    1950
# 64  Laughing on the Outside (Crying on the Inside)      Dinah Shore    1990
#
#     danceability  energy  key  loudness  speechiness  acousticness  liveness  \
# 0          0.487   0.382    7   -10.889       0.0309        0.0422     0.411
# 1          0.556   0.610    9    -4.729       0.2130        0.8330     0.258
# 2          0.533   0.729    7    -7.227       0.0714        0.5630     0.159
# 3          0.715   0.797    3   -10.154       0.1930        0.8370     0.209
# 4          0.552   0.313    5   -12.410       0.0296        0.9160     0.120
# ..           ...     ...  ...       ...          ...           ...       ...
# 60         0.483   0.579    5   -13.923       0.1160        0.4810     0.242
# 61         0.445   0.146    5   -16.064       0.0333        0.9620     0.249
# 62         0.510   0.484   10    -6.942       0.0380        0.7840     0.306
# 63         0.508   0.488    6    -9.486       0.0336        0.8670     0.272
# 64         0.414   0.148    7   -13.059       0.0387        0.9200     0.202
#
#     valence    tempo  duration_ms
# 0     0.714  116.557       261280
# 1     0.665  199.373       171467
# 2     0.884   78.670       111536
# 3     0.841   92.739       144600
# 4     0.303   88.554       202773
# ..      ...      ...          ...
# 60    0.891  122.527       140680
# 61    0.332   86.637       181067
# 62    0.683  103.356       140773
# 63    0.600  100.444       133880
# 64    0.289   65.673       186960
#
# [65 rows x 13 columns]

# %%
cols2scale = ["danceability", "energy", "key", "loudness", "liveness", "valence", "tempo", "duration_ms", "acousticness", "speechiness"]

# Scale the attribute values
songs_scaled_og = StandardScaler().fit_transform(
    songs_df[cols2scale]
)

songs_scaled_og
# Out:
# array([[-0.66220352, -1.02720748,  0.50643942, ...,  0.58550623,
#         -0.89432272, -0.484938  ],
#        [-0.20246625, -0.02197291,  1.06949554, ..., -0.7256738 ,
#          1.65662273,  2.89806462],
#        [-0.35571201,  0.502689  ,  0.50643942, ..., -1.60060649,
#          0.7856626 ,  0.26745962],
#        ...,
#        [ 0.79696261,  0.81572257, -0.05661669, ...,  0.55708197,
#         -1.01161202, -0.31773852],
#        [ 0.71034544,  0.502689  , -1.46425698, ...,  0.92789659,
#         -0.47884248,  5.96338825],
#        [-0.20246625,  1.31393093, -1.46425698, ...,  0.89033336,
#         -0.96819304, -0.24714319]])

# %%
# Create a DataFrame with the scaled data
songs_scaled = pd.DataFrame(songs_scaled_og, columns=cols2scale)

# Copy the tickers names from the original data
songs_scaled["decade"] = songs_df.index

# Set the Ticker column as index
songs_scaled = songs_scaled.set_index("decade")

# Display sample data
songs_scaled.head()
# Out:
#         danceability    energy       key  loudness  liveness   valence  \
# decade
# 0          -0.662204 -1.027207  0.506439 -0.504184  1.717403  0.363120
# 1          -0.202466 -0.021973  1.069496  1.134323  0.607338  0.161596
# 2          -0.355712  0.502689  0.506439  0.469877 -0.110940  1.062285
# 3           0.856928  0.802496 -0.619673 -0.308680  0.251826  0.885437
# 4          -0.229118 -1.331423 -0.056617 -0.908757 -0.393898 -1.327214
#
#            tempo  duration_ms  acousticness  speechiness
# decade
# 0      -0.141088     0.585506     -0.894323    -0.484938
# 1       2.778500    -0.725674      1.656623     2.898065
# 2      -1.476754    -1.600606      0.785663     0.267460
# 3      -0.980766    -1.117905      1.669526     2.526510
# 4      -1.128304    -0.268637      1.924362    -0.509089

# %%
# Create the PCA model instance where n_components=4
pca = PCA(n_components=4)

# %%
# Fit the songs_scaled data to the PCA
songs_pca_data = pca.fit_transform(songs_scaled_og)

# Review the first five rose of the PCA data
# using bracket notation ([0:5])
songs_pca_data[:5]
# Out:
# array([[ 2.71128417e-01,  6.29924721e-01,  5.18297668e-01,
#          3.62261517e-01],
#        [-6.66446878e-01, -8.06036085e-01,  2.54819537e+00,
#          2.62990734e+00],
#        [-4.69677507e-04, -1.50064561e+00,  3.16518828e-01,
#          4.13990683e-01],
#        [-8.40463283e-02, -2.35846157e+00,  2.64037685e-01,
#          1.19381597e+00],
#        [ 2.88617596e+00,  2.94272160e-02, -3.99341842e-01,
#          7.86559853e-03]])

# %%
# Calculate the explained variance
pca.explained_variance_ratio_
# Out:
# array([0.26081851, 0.15145491, 0.12144277, 0.10372028])

# %%
# Extract the component weightings to determine which variables load onto which principal component
pca.components_
# Out:
# array([[-0.2117762 , -0.56662852, -0.02442058, -0.49700432, -0.10796521,
#         -0.29653164, -0.15316495, -0.12816385,  0.47037025, -0.1604748 ],
#        [-0.50287863,  0.08391933,  0.08345771,  0.09347419,  0.00174021,
#         -0.59418609,  0.05661353,  0.53033875, -0.27208679, -0.11319174],
#        [-0.49357126,  0.09845864, -0.09471335,  0.12202854,  0.53006797,
#          0.01588202,  0.47820689, -0.40896305,  0.20996798,  0.03985317],
#        [ 0.03177825, -0.07640246,  0.74576869, -0.08326567,  0.15602009,
#         -0.08650165, -0.02328409,  0.0111958 ,  0.06376584,  0.62728807]])

# %%
cov_mat = np.cov(songs_scaled_og.T)
cor_mat = np.corrcoef(songs_scaled_og.T)
cor_mat
# Out:
# array([[ 1.        ,  0.1232609 , -0.00144256,  0.11450385, -0.0962053 ,
#          0.498088  , -0.13364853, -0.00806283, -0.16136793,  0.13801199],
#        [ 0.1232609 ,  1.        ,  0.01450272,  0.75696873,  0.15834903,
#          0.3676908 ,  0.19639717,  0.14992015, -0.65537549,  0.155016  ],
#        [-0.00144256,  0.01450272,  1.        ,  0.00714781, -0.02130247,
#         -0.02577767,  0.01964281,  0.03265334, -0.04666269,  0.05365131],
#        [ 0.11450385,  0.75696873,  0.00714781,  1.        ,  0.1287848 ,
#          0.20075055,  0.12844059,  0.0700411 , -0.47725864,  0.12064425],
#        [-0.0962053 ,  0.15834903, -0.02130247,  0.1287848 ,  1.        ,
#          0.07184251,  0.02697763, -0.04475277, -0.01447037,  0.0890123 ],
#        [ 0.498088  ,  0.3676908 , -0.02577767,  0.20075055,  0.07184251,
#          1.        ,  0.13855314, -0.25287396, -0.11742125,  0.07543841],
#        [-0.13364853,  0.19639717,  0.01964281,  0.12844059,  0.02697763,
#          0.13855314,  1.        , -0.01791979, -0.10599867,  0.04649785],
#        [-0.00806283,  0.14992015,  0.03265334,  0.0700411 , -0.04475277,
#         -0.25287396, -0.01791979,  1.        , -0.36034728,  0.00203432],
#        [-0.16136793, -0.65537549, -0.04666269, -0.47725864, -0.01447037,
#         -0.11742125, -0.10599867, -0.36034728,  1.        , -0.0858376 ],
#        [ 0.13801199,  0.155016  ,  0.05365131,  0.12064425,  0.0890123 ,
#          0.07543841,  0.04649785,  0.00203432, -0.0858376 ,  1.        ]])

# %%
eig_vals, eig_vecs = np.linalg.eig(cov_mat)
eig_vecs
# Out:
# array([[ 0.2117762 ,  0.50287863,  0.19723488, -0.506956  ,  0.28147573,
#         -0.49357126, -0.2795086 , -0.03054664,  0.05872607,  0.03177825],
#        [ 0.56662852, -0.08391933,  0.75470438,  0.22444221, -0.04830266,
#          0.09845864,  0.16289586,  0.08680866, -0.00112507, -0.07640246],
#        [ 0.02442058, -0.08345771,  0.00268568,  0.01960996,  0.02659947,
#         -0.09471335, -0.02753147,  0.51086997, -0.40552619,  0.74576869],
#        [ 0.49700432, -0.09347419, -0.44753544, -0.09037199,  0.57357549,
#          0.12202854,  0.40375824,  0.14043059,  0.04732616, -0.08326567],
#        [ 0.10796521, -0.00174021, -0.01782232, -0.15473659, -0.00196648,
#          0.53006797, -0.48554006,  0.3022023 ,  0.57592175,  0.15602009],
#        [ 0.29653164,  0.59418609, -0.31115003,  0.58783865, -0.16771391,
#          0.01588202, -0.23622222,  0.07812879, -0.13738806, -0.08650165],
#        [ 0.15316495, -0.05661353,  0.01375898, -0.22794209,  0.13226009,
#          0.47820689, -0.36241811, -0.40197965, -0.61768703, -0.02328409],
#        [ 0.12816385, -0.53033875, -0.06213324,  0.37322902,  0.29724399,
#         -0.40896305, -0.51650269, -0.16447325,  0.09796836,  0.0111958 ],
#        [-0.47037025,  0.27208679,  0.29626537,  0.34006867,  0.67103707,
#          0.20996798,  0.04461226, -0.0136648 ,  0.02608413,  0.06376584],
#        [ 0.1604748 ,  0.11319174, -0.04763953,  0.0875658 , -0.06687747,
#          0.03985317,  0.19974713, -0.65158739,  0.29577346,  0.62728807]])

# %%
tot = sum(eig_vals)
var_exp = [(i / tot)*100 for i in sorted(eig_vals, reverse=True)]
cum_var_exp = np.cumsum(var_exp)
cum_var_exp
# Out:
# array([ 26.08185109,  41.22734161,  53.37161903,  63.74364729,
#         73.81201291,  82.76023194,  90.31408237,  94.58536659,
#         98.4776497 , 100.        ])

# %%
# demonstration that eigen values are the same for covariance and correlation matrices
eig_vals, eig_vecs = np.linalg.eig(cor_mat)
eig_vals
# Out:
# array([2.60818511, 1.51454905, 0.15223503, 0.38922831, 0.42712842,
#        1.21442774, 0.75538504, 0.8948219 , 1.00683656, 1.03720283])

# %%
# Creating a DataFrame with the PCA data
df_songs_pca = pd.DataFrame(songs_pca_data, columns=["PC1", "PC2", "PC3", "PC4"])
toplot_df = df_songs_pca.copy()

# Copy the tickers names from the original data
df_songs_pca["decade"] = songs_df['decade']

# Set the Ticker column as index
df_songs_pca = df_songs_pca.set_index("decade")

# Review the DataFrame
df_songs_pca.head()
# Out:
#              PC1       PC2       PC3       PC4
# decade
# 1960    0.271128  0.629925  0.518298  0.362262
# 1950   -0.666447 -0.806036  2.548195  2.629907
# 1960   -0.000470 -1.500646  0.316519  0.413991
# 1950   -0.084046 -2.358462  0.264038  1.193816
# 1950    2.886176  0.029427 -0.399342  0.007866

# %%
# Determining clusters from 2-7

cluster_num = [f"cluster_{x}" for x in range(2,10)]

song_clusters = []
for n, cn in enumerate(cluster_num):
    model = KMeans(n_clusters=n+2, n_init = 10)

    # Fit the model for the df_songs_pca DataFrame
    model.fit(df_songs_pca)

    # Predict the model segments (clusters)
    this_cluster = model.predict(df_songs_pca)
    temp_df = pd.DataFrame({cn: this_cluster})
    # print(temp_df)
    song_clusters.append(temp_df)

song_cluster_df=pd.concat(song_clusters, axis = 1)
song_cluster_df
# Out:
#       cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  \
# 0             0          0          2          1          1          0
# 1             0          2          3          3          3          2
# 2             0          2          1          0          0          4
# 3             0          2          1          0          0          4
# 4             1          1          0          4          4          5
# ...         ...        ...        ...        ...        ...        ...
# 1805          0          0          1          2          2          3
# 1806          0          2          1          2          2          3
# 1807          0          2          1          2          5          6
# 1808          0          2          3          2          2          3
# 1809          0          2          3          2          5          6
#
#       cluster_8  cluster_9
# 0             7          2
# 1             1          3
# 2             3          1
# 3             3          5
# 4             5          4
# ...         ...        ...
# 1805          2          0
# 1806          2          0
# 1807          2          0
# 1808          0          3
# 1809          4          6
#
# [1810 rows x 8 columns]

# %%
toplot_df["song_name"] = songs_df["song_name"]
toplot_df["artist"]=songs_df["artist"]
toplot_df["decade"]=songs_df["decade"].astype(str)
toplot_df=pd.concat([toplot_df, song_cluster_df], axis = 1)
toplot_df.shape
# Out:
# (1810, 15)

# %%
toplot_df.head(65)
# Out:
#          PC1       PC2       PC3       PC4  \
# 0   0.271128  0.629925  0.518298  0.362262
# 1  -0.666447 -0.806036  2.548195  2.629907
# 2  -0.000470 -1.500646  0.316519  0.413991
# 3  -0.084046 -2.358462  0.264038  1.193816
# 4   2.886176  0.029427 -0.399342  0.007866
# ..       ...       ...       ...       ...
# 60  0.721490 -1.326788  1.114330  0.745435
# 61  3.910729 -0.053974  0.390617  0.308707
# 62  0.962628 -0.791712  1.133838  0.993854
# 63  1.614803 -0.861142  1.075077  0.166709
# 64  3.650070  0.306120 -0.058979  0.689381
#
#                                          song_name           artist decade  \
# 0                                 Suspicious Minds    Elvis Presley   1960
# 1                                 I've Got a Woman      Ray Charles   1950
# 2                              Great Balls Of Fire  Jerry Lee Lewis   1960
# 3                              Roll Over Beethoven      Chuck Berry   1950
# 4                         I Only Have Eyes for You    The Flamingos   1950
# ..                                             ...              ...    ...
# 60                  (You're The) Devil In Disguise    Elvis Presley   1960
# 61           I Don't Want To Set The World On Fire    The Ink Spots   1990
# 62                            A Teenager's Romance     Ricky Nelson   2000
# 63                      There's a Moon Out Tonight       The Capris   1950
# 64  Laughing on the Outside (Crying on the Inside)      Dinah Shore   1990
#
#     cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  \
# 0           0          0          2          1          1          0
# 1           0          2          3          3          3          2
# 2           0          2          1          0          0          4
# 3           0          2          1          0          0          4
# 4           1          1          0          4          4          5
# ..        ...        ...        ...        ...        ...        ...
# 60          1          1          0          0          0          4
# 61          1          1          0          4          4          5
# 62          1          1          0          0          0          4
# 63          1          1          0          0          0          4
# 64          1          1          0          4          4          5
#
#     cluster_8  cluster_9
# 0           7          2
# 1           1          3
# 2           3          1
# 3           3          5
# 4           5          4
# ..        ...        ...
# 60          3          1
# 61          5          4
# 62          3          1
# 63          3          5
# 64          5          4
#
# [65 rows x 15 columns]

# %%
toplot_df.dropna()
# Out:
#            PC1       PC2       PC3       PC4                     song_name  \
# 0     0.271128  0.629925  0.518298  0.362262              Suspicious Minds
# 1    -0.666447 -0.806036  2.548195  2.629907              I've Got a Woman
# 2    -0.000470 -1.500646  0.316519  0.413991           Great Balls Of Fire
# 3    -0.084046 -2.358462  0.264038  1.193816           Roll Over Beethoven
# 4     2.886176  0.029427 -0.399342  0.007866      I Only Have Eyes for You
# ...        ...       ...       ...       ...                           ...
# 1805 -0.917927  0.524654 -1.033298  0.632751           Party In The U.S.A.
# 1806 -1.134177 -0.932461 -1.052827  0.300490  Can't Get You out of My Head
# 1807 -1.298489  0.285540 -1.374582 -0.484277                     Unwritten
# 1808 -2.270271 -0.091437 -0.663547  2.401243                  American Boy
# 1809 -2.202752  0.717052  0.262289 -1.375260               Dani California
#
#                      artist decade  cluster_2  cluster_3  cluster_4  \
# 0             Elvis Presley   1960          0          0          2
# 1               Ray Charles   1950          0          2          3
# 2           Jerry Lee Lewis   1960          0          2          1
# 3               Chuck Berry   1950          0          2          1
# 4             The Flamingos   1950          1          1          0
# ...                     ...    ...        ...        ...        ...
# 1805            Miley Cyrus   2000          0          0          1
# 1806          Kylie Minogue   2000          0          2          1
# 1807    Natasha Bedingfield   2000          0          2          1
# 1808                Estelle   2000          0          2          3
# 1809  Red Hot Chili Peppers   2000          0          2          3
#
#       cluster_5  cluster_6  cluster_7  cluster_8  cluster_9
# 0             1          1          0          7          2
# 1             3          3          2          1          3
# 2             0          0          4          3          1
# 3             0          0          4          3          5
# 4             4          4          5          5          4
# ...         ...        ...        ...        ...        ...
# 1805          2          2          3          2          0
# 1806          2          2          3          2          0
# 1807          2          5          6          2          0
# 1808          2          2          3          0          3
# 1809          2          5          6          4          6
#
# [1810 rows x 15 columns]

# %%
toplot_df.shape
# Out:
# (1810, 15)

# %%
# save data to json file for plotting on website
# toplot_df.to_json(r'pca_data.json')

# %%
bydec_df = toplot_df.copy()
bydec_df = bydec_df.groupby("decade")
bydec_df = bydec_df.mean()
bydec_df
# Out:
# C:\Users\Jen\AppData\Local\Temp\ipykernel_38676\3499961453.py:3: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#              PC1       PC2       PC3       PC4  cluster_2  cluster_3  \
# decade
# 1950    1.565346 -0.822397  0.529470  0.175083   0.715232   1.317881
# 1960    0.869686 -0.450995  0.442184 -0.054676   0.575610   1.307317
# 1970    0.142834  0.134661 -0.222912 -0.032405   0.388679   1.207547
# 1980   -0.456116 -0.035012 -0.482334 -0.186887   0.206612   1.338843
# 1990   -0.174339  0.373209 -0.070555  0.022547   0.275488   1.084599
# 2000   -0.538587  0.035750  0.077623  0.058007   0.226337   1.240741
#
#         cluster_4  cluster_5  cluster_6  cluster_7  cluster_8  cluster_9
# decade
# 1950     0.728477   1.887417   1.953642   4.006623   3.417219   3.635762
# 1960     1.053659   1.756098   2.204878   3.717073   3.643902   3.526829
# 1970     1.249057   1.837736   2.641509   3.267925   4.173585   3.950943
# 1980     1.421488   1.822314   2.847107   3.384298   3.859504   3.669421
# 1990     1.514100   1.900217   2.622560   2.967462   4.002169   4.080260
# 2000     1.580247   1.833333   2.473251   3.230453   3.510288   4.374486

# %%
import plotly
import plotly.graph_objs as go
markercolor = toplot_df['cluster_2']
xdata = 'PC1'
ydata = 'PC2'
zdata = 'PC3'

fig1 = go.Scatter3d(x=toplot_df[xdata],
                    y=toplot_df[ydata],
                    z=toplot_df[zdata],
                    hovertemplate =
                    '<b>Song: </b>%{text}'+
                    '<extra></extra>',
                    text = '<b>'+ toplot_df.song_name + '</b><br> Artist: ' + toplot_df.artist +'<br> Decade: ' + toplot_df.decade.astype(str),
                    marker=dict(color = markercolor,
                                opacity=0.9,
                                reversescale=True,
                                colorscale='jet',
                                size=5),
                    line=dict (width=0.02),
                    mode='markers')

#Make Plot.ly Layout
mylayout = go.Layout(scene=dict(xaxis=dict( title=xdata),
                                yaxis=dict( title=ydata),
                                zaxis=dict(title=zdata)),)

#Plot and save html
plotly.offline.plot({"data": [fig1],
                     "layout": mylayout},
                     auto_open=True,
                     filename=("3DPlot.html"))
# Out:
# '3DPlot.html'

# %%
X = songs_scaled
cov = (X.T @ X) / (X.shape[0] - 1)
eig_values, eig_vectors = np.linalg.eig(cov)
eig_values.sort()
eig_values
# Out:
# array([0.15231918, 0.38944347, 0.42736454, 0.75580261, 0.89531655,
#        1.00739313, 1.03777618, 1.21509907, 1.51538628, 2.60962689])

# %%
eig_vectors.size
# Out:
# 100
