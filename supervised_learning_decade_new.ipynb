# %%
# Import the required modules
import pandas as pd
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %% [markdown]
# ## Step 1: Read in the dataset about the current songs' decades of the playlists.

# %%
# Read the songs_features.csv file from the Resources folder into a Pandas DataFrame
songs_df = pd.read_csv(
    Path("../Project4-main/Database/final.csv")
)

# Review the DataFrame
display(songs_df.head())
display(songs_df.tail())
# Out:
#                        id                                song_name  \
# 0  4Vn7TykT27PIygBiZjTR2s         Hotel California - 2013 Remaster
# 1  2WfaOiMkCvy7F5fcp2zZ8L                               Take on Me
# 2  5ChkMS8OtdzJeqyybCc9R5                              Billie Jean
# 3  4jDmJ51x1o9NZB5Nxxc7gY                         Careless Whisper
# 4  5C0LFQARavkPpn7JgA4sLk  Every Breath You Take - Remastered 2003
#
#             artist                                            pic_url  \
# 0           Eagles  https://i.scdn.co/image/ab67616d0000b273061849...
# 1             a-ha  https://i.scdn.co/image/ab67616d0000b273e8dd4d...
# 2  Michael Jackson  https://i.scdn.co/image/ab67616d0000b2734121fa...
# 3   George Michael  https://i.scdn.co/image/ab67616d0000b27364c19b...
# 4       The Police  https://i.scdn.co/image/ab67616d0000b27307ea1b...
#
#                                          preview_url  release_year  decade  \
# 0  https://p.scdn.co/mp3-preview/6fedc11d0f55bef1...          2003    2000
# 1  https://p.scdn.co/mp3-preview/ed66a8c444c35b2f...          1985    1980
# 2  https://p.scdn.co/mp3-preview/0f6b8a3524ec4100...          2008    2000
# 3  https://p.scdn.co/mp3-preview/426887696731457a...          1998    1990
# 4                                                NaN          1983    1980
#
#    danceability  energy  key  ...  instrumentalness  liveness  valence  \
# 0         0.579   0.508    2  ...          0.000494    0.0575    0.609
# 1         0.573   0.902    6  ...          0.001250    0.0928    0.876
# 2         0.920   0.654   11  ...          0.015300    0.0360    0.847
# 3         0.574   0.628    2  ...          0.000000    0.2710    0.803
# 4         0.820   0.452    1  ...          0.002940    0.0701    0.740
#
#      tempo            type                                   uri  \
# 0  147.125  audio_features  spotify:track:4Vn7TykT27PIygBiZjTR2s
# 1   84.412  audio_features  spotify:track:2WfaOiMkCvy7F5fcp2zZ8L
# 2  117.046  audio_features  spotify:track:5ChkMS8OtdzJeqyybCc9R5
# 3  153.119  audio_features  spotify:track:4jDmJ51x1o9NZB5Nxxc7gY
# 4  117.401  audio_features  spotify:track:5C0LFQARavkPpn7JgA4sLk
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4Vn7TykT27PI...
# 1  https://api.spotify.com/v1/tracks/2WfaOiMkCvy7...
# 2  https://api.spotify.com/v1/tracks/5ChkMS8OtdzJ...
# 3  https://api.spotify.com/v1/tracks/4jDmJ51x1o9N...
# 4  https://api.spotify.com/v1/tracks/5C0LFQARavkP...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4Vn7...      391376
# 1  https://api.spotify.com/v1/audio-analysis/2Wfa...      225280
# 2  https://api.spotify.com/v1/audio-analysis/5Chk...      293827
# 3  https://api.spotify.com/v1/audio-analysis/4jDm...      300107
# 4  https://api.spotify.com/v1/audio-analysis/5C0L...      253250
#
#   time_signature
# 0              4
# 1              4
# 2              4
# 3              4
# 4              4
#
# [5 rows x 24 columns]
#                          id                     song_name  \
# 862  3E7ZwUMJFqpsDOJzEkBrQ7  Can't Get You out of My Head
# 863  3U5JVgI2x4rDyHGObzJfNf                     Unwritten
# 864  6etwirSInfuJrSOlogS6Sh                  American Boy
# 865  70wYA8oYHoMzhRRkARoMhU           When You Were Young
# 866  10Nmj3JCNoMeBQ87uw5j8k               Dani California
#
#                     artist                                            pic_url  \
# 862          Kylie Minogue  https://i.scdn.co/image/ab67616d0000b2735d6121...
# 863    Natasha Bedingfield  https://i.scdn.co/image/ab67616d0000b273b337e1...
# 864                Estelle  https://i.scdn.co/image/ab67616d0000b27398dc3e...
# 865            The Killers  https://i.scdn.co/image/ab67616d0000b2734f87f1...
# 866  Red Hot Chili Peppers  https://i.scdn.co/image/ab67616d0000b27309fd83...
#
#                                            preview_url  release_year  decade  \
# 862  https://p.scdn.co/mp3-preview/80a42bfd505424a4...          2001    2000
# 863  https://p.scdn.co/mp3-preview/5559460cc3e2c5aa...          2004    2000
# 864  https://p.scdn.co/mp3-preview/6f51d610e0fcdf1a...          2008    2000
# 865                                                NaN          2006    2000
# 866  https://p.scdn.co/mp3-preview/0454b7cef05f7db7...          2006    2000
#
#      danceability  energy  key  ...  instrumentalness  liveness  valence  \
# 862         0.766   0.563    9  ...          0.683000    0.1150    0.964
# 863         0.706   0.800    5  ...          0.000000    0.0822    0.629
# 864         0.693   0.729    0  ...          0.000000    0.0700    0.521
# 865         0.467   0.988   11  ...          0.048400    0.2800    0.321
# 866         0.556   0.913    0  ...          0.000009    0.3460    0.730
#
#        tempo            type                                   uri  \
# 862  126.007  audio_features  spotify:track:3E7ZwUMJFqpsDOJzEkBrQ7
# 863  100.011  audio_features  spotify:track:3U5JVgI2x4rDyHGObzJfNf
# 864  117.848  audio_features  spotify:track:6etwirSInfuJrSOlogS6Sh
# 865  130.433  audio_features  spotify:track:70wYA8oYHoMzhRRkARoMhU
# 866   96.184  audio_features  spotify:track:10Nmj3JCNoMeBQ87uw5j8k
#
#                                             track_href  \
# 862  https://api.spotify.com/v1/tracks/3E7ZwUMJFqps...
# 863  https://api.spotify.com/v1/tracks/3U5JVgI2x4rD...
# 864  https://api.spotify.com/v1/tracks/6etwirSInfuJ...
# 865  https://api.spotify.com/v1/tracks/70wYA8oYHoMz...
# 866  https://api.spotify.com/v1/tracks/10Nmj3JCNoMe...
#
#                                           analysis_url duration_ms  \
# 862  https://api.spotify.com/v1/audio-analysis/3E7Z...      230640
# 863  https://api.spotify.com/v1/audio-analysis/3U5J...      259333
# 864  https://api.spotify.com/v1/audio-analysis/6etw...      284733
# 865  https://api.spotify.com/v1/audio-analysis/70wY...      220427
# 866  https://api.spotify.com/v1/audio-analysis/10Nm...      282160
#
#     time_signature
# 862              4
# 863              4
# 864              4
# 865              4
# 866              4
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Step 2: Split the data into X and y and then into testing and training sets.

# %%
#drop irrelvant columns that are not used to specify song attributes or decade
temp_df = songs_df.drop(columns=['id', 'song_name', 'artist', 'pic_url', 'preview_url', 'release_year', 'type', 'uri', 'track_href', 'analysis_url'])

# Split the data into X (features) and y (target)
# The y variable should focus on the target column
y = temp_df['decade']

# The X variable should include all features except the target
X = temp_df.drop(columns=['decade'])

# %%
# Split into testing and training sets using train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# ## Step 3: Fit a logistic regression classifier.

# %%
# Declare a logistic regression model.
# Apply a random_state of 9 to the model
logistic_regression_model = LogisticRegression(random_state=9)

# Fit and save the logistic regression model using the training data
lr_model = logistic_regression_model.fit(X_train, y_train)

# %% [markdown]
# ## Step 4: Create the predicted values for the testing and the training data.

# %%
#Generate training predictions
training_predictions = lr_model.predict(X_train)

#Generate testing predictions
testing_predictions = logistic_regression_model.predict(X_test)

# %% [markdown]
# ## Step 5: Print a confusion matrix for the training data.

# %%
# Import the model for sklearn confusion matrix
from sklearn.metrics import confusion_matrix

# Create and save the confusion matrix for the training data
training_matrix = confusion_matrix(y_train, training_predictions)

# Print the confusion matrix for the training data
print(training_matrix)
# Out:
# [[ 0 35  0  8  6  0]
#  [ 0 82  0 26 14  0]
#  [ 0 33  0 43 48  0]
#  [ 0 25  0 62 42  0]
#  [ 0 24  0 50 55  0]
#  [ 0 27  0 39 31  0]]

# %% [markdown]
# ## Step 6: Pring a confusion matrix for the testing data.

# %%
# Create and save the confusion matrix for the testing data
test_matrix = confusion_matrix(y_test, testing_predictions)

# Print the confusion matrix for the testing data
print(test_matrix)
# Out:
# [[ 0 11  0  6  0  0]
#  [ 0 24  0 11  4  0]
#  [ 0 11  0 13 11  0]
#  [ 0 11  0 17 18  0]
#  [ 0 15  0 17 17  0]
#  [ 0 11  0 12  8  0]]

# %% [markdown]
# ## Step 7: Print the training classification report.

# %%
# Create and save the training classification report
training_report = classification_report(y_train, training_predictions)

# Print the training classification report
print(training_report)
# Out:
#               precision    recall  f1-score   support
#
#         1950       0.00      0.00      0.00        49
#         1960       0.36      0.67      0.47       122
#         1970       0.00      0.00      0.00       124
#         1980       0.27      0.48      0.35       129
#         1990       0.28      0.43      0.34       129
#         2000       0.00      0.00      0.00        97
#
#     accuracy                           0.31       650
#    macro avg       0.15      0.26      0.19       650
# weighted avg       0.18      0.31      0.22       650
# c:\Users\roxan\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\roxan\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\roxan\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Step 8: Print the testing classification report.

# %%
# Create and save the testing classification report
testing_report = classification_report(y_test, testing_predictions)

# Print the testing classification report
print(testing_report)
# Out:
#               precision    recall  f1-score   support
#
#         1950       0.00      0.00      0.00        17
#         1960       0.29      0.62      0.39        39
#         1970       0.00      0.00      0.00        35
#         1980       0.22      0.37      0.28        46
#         1990       0.29      0.35      0.32        49
#         2000       0.00      0.00      0.00        31
#
#     accuracy                           0.27       217
#    macro avg       0.13      0.22      0.16       217
# weighted avg       0.17      0.27      0.20       217
# c:\Users\roxan\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\roxan\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\roxan\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
